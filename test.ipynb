# %%
from langchain.llms import Ollama

# %%
model=Ollama(base_url="http://localhost:11434",model="llama3")

# %%
model("hi can you tell me the most significat research in the field of AI?")
# Out:
# c:\Users\rs180\OneDrive\Desktop\ollama\.conda\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model("hi can you tell me the most significat research in the field of AI?")
#
# File c:\Users\rs180\OneDrive\Desktop\ollama\.conda\Lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# ...

# %%
model("hi can you tell me the about AI?")
# Out:
# "Artificial Intelligence (AI) is a broad field that deals with creating intelligent machines that can perform tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data and improve their performance over time.\n2. **Problem-solving**: AI can solve complex problems, make decisions, and take actions based on those decisions.\n3. **Perception**: AI can perceive its environment through sensors, cameras, or other means.\n\nAI has many applications across industries, including:\n\n1. **Robotics**: Industrial robots, service robots, and autonomous vehicles.\n2. **Computer Vision**: Image recognition, object detection, facial recognition, and surveillance systems.\n3. **Natural Language Processing (NLP)**: Chatbots, virtual assistants, language translation, and text summarization.\n4. **Expert Systems**: Knowledge-based systems that mimic human decision-making in specific domains.\n\nSome popular AI techniques include:\n\n1. **Machine Learnin
# ...
